# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %% [markdown]
# # Ques 1:-

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.naukri.com/')

# %%
designation=driver.find_element(By.XPATH,"/html/body/div[1]/div[7]/div/div/div[1]/div/div/div/div[1]/div/input")
designation.send_keys('Data Scientist')

# %%
search=driver.find_element(By.XPATH,"/html/body/div[1]/div[7]/div/div/div[6]")
search.click()

# %%
location_filter=driver.find_element(By.XPATH,'/html/body/div/div/main/div[1]/div[1]/div/div/div[2]/div[5]/div[2]/div[2]/label/p/span[1]')
location_filter.click()

# %%
salary_filter=driver.find_element(By.XPATH,'/html/body/div/div/main/div[1]/div[1]/div/div/div[2]/div[6]/div[2]/div[2]/label/p/span[1]')
salary_filter.click()

# %%
titles = driver.find_elements(By.XPATH,'//a[@class="title "]')
job_title = [i.text for i in titles[:10]]

# %%
location = driver.find_elements(By.XPATH,'//span[@class="locWdth"]')
job_loc = [i.text for i in location[:10]]

# %%
comp = driver.find_elements(By.XPATH,'//a[@class=" comp-name mw-25"]')
company_name = [i.text for i in comp[:10]]

# %%
experience = driver.find_elements(By.XPATH,'//span[@class="expwdth"]')
job_exp= [i.text for i in experience[:10]]

# %%
data = {'Job Title':job_title,'Job Location':job_loc,'Experince required':job_exp,'Company':company_name}
df = pd.DataFrame(data)
df
# Out:
#                                Job Title  \
# 0                         Data Scientist
# 1  Senior Data Scientist/ Data Scientist
# 2                         Data Scientist
# 3                         Data Scientist
# 4                         Data Scientist
# 5
# 6
# 7
# 8                  Python Data Scientist
# 9               Associate Data Scientist
#
#                                         Job Location Experince required  \
# 0  Kolkata, Mumbai, New Delhi, Hyderabad, Pune, C...            2-7 Yrs
# 1         Mumbai, Pune, Chennai, Gurugram, Bengaluru            3-7 Yrs
# 2                                Gurugram, Bengaluru            3-7 Yrs
# 3  Kolkata, Mumbai, New Delhi, Hyderabad, Pune, C...            2-7 Yrs
# 4  Kolkata, Mumbai, New Delhi, Hyderabad, Pune, C...            1-2 Yrs
# 5  Kolkata, Mumbai, New Delhi, Hyderabad, Pune, C...            1-2 Yrs
# 6  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...            3-7 Yrs
# ...

# %% [markdown]
# # Ques 2:-

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.shine.com/')

# %%
designation=driver.find_element(By.XPATH,'/html/body/div/div[4]/div/div[2]/div[2]/div/form/div/div[1]/ul/li[1]/div/input')
designation.send_keys('Data Scientist')

# %%
location=driver.find_element(By.XPATH,'/html/body/div/div[4]/div/div[2]/div[2]/div/form/div/div[1]/ul/li[2]/div/input')
location.send_keys('Banglore')

# %%
search=driver.find_element(By.XPATH,'/html/body/div/div[4]/div/div[2]/div[2]/div/form/div/div[2]/div/button')
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
# extracting the first 10 job titles
titles=driver.find_elements(By.XPATH,'//strong[@class="jobCard_pReplaceH2__xWmHg"]/a')
job_title = [i.text for i in titles[:10]]

# %%
location = driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2"]')
job_location = [i.text for i in location[:10]]

# %%
company = driver.find_elements(By.XPATH,'//div[@class="jobCard_jobCard_cName__mYnow"]/span')
company_name = [i.text for i in company[:10]]

# %%
experience = driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_jobIcon__3FB1t"]')
experience_required= [i.text for i in experience[:10]]

# %%
data = {'Job Title':job_title,'Job Location':job_location,'Experince required':experience_required,'Company':company_name}
df = pd.DataFrame(data)
df
# Out:
#                            Job Title     Job Location Experince required  \
# 0                     Data Scientist  Mumbai City\n+4        5 to 10 Yrs
# 1  Data Scientist Urgent Recruitment        Oman\n+13         0 to 4 Yrs
# 2             Data Scientist Opening        Oman\n+13         0 to 4 Yrs
# 3         Data Scientist Recruitment        Oman\n+12         0 to 4 Yrs
# 4             Data Scientist Vacancy        Oman\n+13         0 to 4 Yrs
# 5          Hiring For Data Scientist        Oman\n+13         0 to 4 Yrs
# 6             Data Scientist Opening      Canada\n+15         0 to 4 Yrs
# 7             Data Scientist Opening      Canada\n+15         0 to 4 Yrs
# 8         Data Scientist Recruitment  Mumbai City\n+9         0 to 4 Yrs
# 9                  ML Data Scientist    Bangalore\n+3         5 to 8 Yrs
#
#                                   Company
# 0  alike thoughts solutions private li...
# 1                 divya staffing solution
# ...

# %% [markdown]
# # Ques 3:-

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&marketplace=FLIPKART')

# %%
Rating=[]
Review_summary=[]
Full_review=[]

# %%
start = 0
end = 11
for page in range(start,end):
    rate = driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
    for i in rate:
        Rating.append(i.text)
        revw = driver.find_elements(By.CLASS_NAME,'_2-N8zT')
    for j in revw:
        Review_summary.append(j.text)
    full_r = driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
    for k in full_r:
        Full_review.append(k.text)
    
    next_button = driver.find_element(By.CLASS_NAME,'_1LKTO3')
    next_button.click()
    time.sleep(3)

# %%
import pandas as pd
df=pd.DataFrame({'rating':Rating,'review_summary':Review_summary,'full_review':Full_review})
df
# Out:
#     rating       review_summary  \
# 0        5            Excellent
# 1        5     Perfect product!
# 2        5    Worth every penny
# 3        5  Best in the market!
# 4        5            Wonderful
# ..     ...                  ...
# 105      5    Terrific purchase
# 106      5       Classy product
# 107      5            Must buy!
# 108      5             Terrific
# 109      5            Just wow!
#
#                                            full_review
# 0                                                  NYC
# 1                                         Photos super
# 2    Feeling awesome after getting the delivery of ...
# 3                                          Good Camera
# 4                               This is amazing at all
# ..                                                 ...
# 105                                  Value for money 😍
# 106  Camera is awesome\nBest battery backup\nA perf...
# 107                                It’s really awesome
# ...

# %% [markdown]
# # Ques 4:-

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.flipkart.com/')

# %%
product=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div/div/div/div[1]/div/div[1]/div/div[1]/div[1]/header/div[1]/div[2]/form/div/div/input')
product.send_keys('Sneakers')

# %%
search_button=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div/div/div/div[1]/div/div[1]/div/div[1]/div[1]/header/div[1]/div[2]/form/div/button')
search_button.click()

# %%
Brand=[]
for page in range(0,5):
    brand = driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in brand[0:100]:
        Brand.append(i.text)
    next_button = driver.find_element(By.CLASS_NAME,'_1LKTO3')
    next_button.click()
    time.sleep(3)
    
Brand = Brand[0:100]

# %%
product_desc = []
for page in range(0,5):
    product = driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in product[0:100]:
        product_desc.append(i.text)
    next_button = driver.find_element(By.CLASS_NAME,'_1LKTO3')
    next_button.click()
    time.sleep(3)
    
product_desc = product_desc[0:100]

# %%
price = []
for page in range(0,5):
    prc = driver.find_elements(By.CLASS_NAME,'_30jeq3')
    for i in prc[0:100]:
        price.append(i.text)
    next_button = driver.find_element(By.CLASS_NAME,'_1LKTO3')
    next_button.click()
    time.sleep(3)
    
price = price[0:100]

# %%
import pandas as pd
df = pd.DataFrame({'Brand':Brand,'product_desc':product_desc,'price':price})
df
# Out:
#         Brand                                       product_desc   price
# 0      BRUTON  Lightweight Comfort Summer Trendy Premium Styl...    ₹499
# 1    RED TAPE  Casual Sneakers Shoes for Men | Soft Cushioned...  ₹2,189
# 2    URBANBOX                 Coy Float Slip On Sneakers For Men    ₹299
# 3   Deals4you                   Street Legacy U Sneakers For Men    ₹379
# 4    RapidBox                     Shuffle Ultra Sneakers For Men    ₹595
# ..        ...                                                ...     ...
# 95       aadi                                   Sneakers For Men    ₹449
# 96     BRUTON  Carnival-02 Mens High Top Casual Chunky Fashio...    ₹449
# 97     BRUTON  Airson Arcade | Casual Sneakers Shoes | Sneake...    ₹499
# 98       PUMA                                   Sneakers For Men    ₹879
# 99      Abros                          Designer Sneakers For Men    ₹738
#
# [100 rows x 3 columns]

# %% [markdown]
# # Ques 5:-

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.amazon.in/')

# %%
product=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input')
product.send_keys('Laptop')

# %%
search_button=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input')
search_button.click()

# %%
cpu_type=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[6]/ul[19]/span/span[9]/li/span/a/span')
cpu_type.click()

# %%
title = []
ttl = driver.find_elements(By.XPATH,'//h2[@class="a-size-mini a-spacing-none a-color-base s-line-clamp-2"]')
for i in ttl[0:10]:
    title.append(i.text)

# %%
rating  = []
rate = driver.find_elements(By.XPATH,'//div[@class="a-row a-size-small"]/span[2]')
for i in rate[0:10]:
    rating.append(i.text)

# %%
price  = []
prc = driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
for i in prc[0:10]:
    price.append(i.text)

# %%
df = pd.DataFrame({'title':title,'rating':rating,'price':price})
df
# Out:
#                                                title rating     price
# 0  MSI Modern 14, Intel 12th Gen. i7-1255U, 36CM ...    102    49,650
# 1  MSI Modern 15, Intel 13th Gen. i7-1355U, 40CM ...     12    65,990
# 2  ASUS Vivobook 15, Intel Core i7-12650H 12th Ge...    466    64,990
# 3  ASUS TUF Gaming F15, 15.6"(39.62 cms) FHD 144H...    254    72,990
# 4  Lenovo IdeaPad Slim 3 Intel Core i7 12th Gen 1...    470    62,990
# 5  HP OMEN Gaming Laptop, Intel Core i7-14700HX (...      4  1,14,590
# 6  Lenovo ThinkBook 15 Intel 12th Gen Core i7 15....      7  1,38,990
# 7  Dell Inspiron 5430 Laptop, 13th Gen Intel Core...      3    57,990
# 8  HP Victus Gaming Laptop, 12th Gen Intel Core i...     95    86,490
# 9  Lenovo IdeaPad Slim 5 Intel Core i7 13700H 16"...    379    79,990

# %% [markdown]
# # Ques 6:-

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.azquotes.com/')

# %%
top_quote=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[1]/div/div[3]/ul/li[5]/a')
top_quote.click()

# %%
Quotes = []
for page in range(0,10):
    a = driver.find_elements(By.XPATH,'//div[@class="wrap-block"]/p/a[2]')
    for i in a:
        Quotes.append(i.text)
    next_button = driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div/div/div/div[1]/div/div[3]/li[12]/a')
    next_button.click()
    time.sleep(3)

# %%
Author = []
for page in range(0,10):
    b = driver.find_elements(By.XPATH,'//div[@class="author"]/a')
    for i in b:
        Author.append(i.text)
    next_button = driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div/div/div/div[1]/div/div[3]/li[12]/a')
    next_button.click()
    time.sleep(3)

# %%
type_of_Quotes = []
for page in range(0,10):
    c = driver.find_elements(By.XPATH,'//div[@class="tags"]')
    for i in c:
        type_of_Quotes.append(i.text)
    next_button = driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div/div/div/div[1]/div/div[3]/li[12]/a')
    next_button.click()
    time.sleep(3)

# %%
df = pd.DataFrame({'Quotes':Quotes,'Author':Author,'type_of_Quotes':type_of_Quotes})
df
# Out:
#                                                 Quotes  \
# 0    The essence of strategy is choosing what not t...
# 1    One cannot and must not try to erase the past ...
# 2    Patriotism means to stand by the country. It d...
# 3    Death is something inevitable. When a man has ...
# 4    You have to love a nation that celebrates its ...
# ..                                                 ...
# 995  Regret for the things we did can be tempered b...
# 996  America... just a nation of two hundred millio...
# 997  For every disciplined effort there is a multip...
# 998  The spiritual journey is individual, highly pe...
# 999  The mind is not a vessel to be filled but a fi...
#
#                      Author                            type_of_Quotes
# 0            Amelia Earhart  Essence, Deep Thought, Transcendentalism
# 1          Ludwig von Mises                 Inspiration, Past, Trying
# 2    Elizabeth Cady Stanton                       Country, Peace, War
# ...

# %% [markdown]
# # Ques 7:-

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.jagranjosh.com/general-knowledge/list-of-all-prime-ministers-of-india-1473165149-1')

# %%
name = []
for i in driver.find_elements(By.XPATH,'//div[@class="TableData"]/table/tbody/tr/td[2]/div'):
    name.append(i.text)

# %%
Born_Dead = []
for i in driver.find_elements(By.XPATH,'//div[@class="TableData"]/table/tbody/tr/td[3]'):
    Born_Dead.append(i.text)

# %%
Term_of_office = []
for i in driver.find_elements(By.XPATH,'//div[@class="TableData"]/table/tbody/tr/td[4]'):
    Term_of_office.append(i.text.replace('\n',' '))

# %%
Remark = []
for i in driver.find_elements(By.XPATH,'//div[@class="TableData"]/table/tbody/tr/td[5]'):
    Remark.append(i.text)

# %%
df = pd.DataFrame({'name':name,'Born_Dead':Born_Dead,'Term_of_office':Term_of_office,'Remark':Remark})
df
# Out:
#                            name     Born_Dead  \
# 0             Jawahar Lal Nehru   (1889–1964)
# 1     Gulzarilal Nanda (Acting)   (1898-1998)
# 2           Lal Bahadur Shastri   (1904–1966)
# 3   Gulzari Lal Nanda  (Acting)   (1898-1998)
# 4                 Indira Gandhi   (1917–1984)
# 5                 Morarji Desai   (1896–1995)
# 6                  Charan Singh   (1902–1987)
# 7                 Indira Gandhi   (1917–1984)
# 8                  Rajiv Gandhi   (1944–1991)
# 9                   V. P. Singh   (1931–2008)
# 10              Chandra Shekhar   (1927–2007)
# 11          P. V. Narasimha Rao   (1921–2004)
# 12         Atal Bihari Vajpayee  (1924- 2018)
# 13             H. D. Deve Gowda   (born 1933)
# 14           Inder Kumar Gujral   (1919–2012)
# 15         Atal Bihari Vajpayee   (1924-2018)
# 16               Manmohan Singh   (born 1932)
# 17                Narendra Modi   (born 1950)
# 18                Narendra Modi   (born 1950)
#
# ...

# %% [markdown]
# # Ques 8:-

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.motor1.com/')

# %%
description=driver.find_element(By.XPATH,'/html/body/div[9]/div[2]/div/div/div[3]/div/div/div/form/input')
description.send_keys('50 most expensive cars in the world')

# %%
search_button=driver.find_element(By.XPATH,'/html/body/div[9]/div[2]/div/div/div[3]/div/div/div/form/button[1]')
search_button.click()

# %%
page=driver.find_element(By.XPATH,'/html/body/div[9]/div[9]/div/div[1]/div/div/div[1]/div/div[1]/h3/a')
page.click()

# %%
car_name=[]
name=driver.find_elements(By.XPATH,'//h3[@class="subheader"]')
for i in name:
    car_name.append(i.text)
    
car_name=car_name[:50]

# %%
car_price=[]
price=driver.find_elements(By.XPATH,'//p[strong]')
for n in price:
    car_price.append(n.text)
    
car_price=car_price[:50]

# %%
import pandas as pd
df=pd.DataFrame({'car_name':car_name,'price':car_price})
df
# Out:
#                               car_name                        price
# 0                  Aston Martin Valour          Price: $1.5 Million
# 1                         McLaren Elva          Price: $1.7 Million
# 2                          Czinger 21C          Price: $1.7 Million
# 3                        Ferrari Monza          Price: $1.7 Million
# 4                   Gordon Murray T.33          Price: $1.7 Million
# 5                    Koenigsegg Gemera          Price: $1.7 Million
# 6                          Zenvo TSR-S          Price: $1.7 Million
# 7                   Hennessey Venom F5          Price: $1.8 Million
# 8                      Bentley Bacalar          Price: $1.9 Million
# 9        Hispano Suiza Carmen Boulogne          Price: $1.9 Million
# 10              Bentley Mulliner Batur          Price: $2.0 Million
# 11                        Deus Vayanne          Price: $2.0 Million
# 12                         SSC Tuatara          Price: $2.0 Million
# ...
